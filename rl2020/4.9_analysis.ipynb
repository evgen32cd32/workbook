# %%
import pandas as pd
dfs = []
for ph in [0.4, 0.25, 0.55]:
    dfs.append(pd.read_csv(f'4.9_q_{ph}.csv'))

pd.set_option('display.max_rows', 100)

# %%
dfs[0].std()
# Out:
# Unnamed: 0    14.577380
# 1                   NaN
# 2              0.001070
# 3              0.001225
# 4              0.000711
# 5              0.001011
# 6              0.001208
# 7              0.000957
# 8              0.000814
# 9              0.001052
# 10             0.001299
# 11             0.001648
# 12             0.002079
# 13             0.002804
# 14             0.002408
# 15             0.001776
# 16             0.001517
# 17             0.001439
# 18             0.002074
# 19             0.002913
# 20             0.003111
# 21             0.003330
# 22             0.003913
# 23             0.004360
# 24             0.005123
# 25             0.006461
# 26             0.007089
# 27             0.006730
# 28             0.006076
# 29             0.005185
# 30             0.004370
# 31             0.004021
# 32             0.003701
# 33             0.003229
# 34             0.003310
# 35             0.003976
# 36             0.004905
# 37             0.006048
# ...
